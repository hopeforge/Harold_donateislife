# %%
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json
import pandas as pd

from pandas.io.json import json_normalize

import csv
import re #regular expression

# %%
#Twitter credentials for the app
consumer_key = 'b0Mp2hczge9oIhwLTHvXaYGY0'
consumer_secret = 'HaL5zMnpe0PJ0YsBDNYPIFOTEZpqdRok7tqGEtajhh425wThBW'
access_key= '58998497-RPJZlqbrmnN35TZ3pOZJ3rMR82rzeWumPipqfM2HA'
access_secret = 'EtzjpDB2NV7YnTQzX2WBhTW44LugETZwao4bexykU4GoO'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# %%
start_date = '2019-01-01'
end_date = '2019-12-31'

tweets = []
def write_tweets(keyword, file):
    data = {'search_phrase': [], 
        'text': [], 
        'screen_name': [], 
        'created_at': [],
        'retweet_count': [], 
        'favorite_count': [],
        'friends_count': [], 
        'followers_count': [],
        'user_id' : [],
        'user_name' : [],
        'user_location' : [],
        'user_description' : []
       }

    #page attribute in tweepy.cursor and iteration
    for page in tweepy.Cursor(api.search, q=keyword,
                              count=100, include_rts=True, since=start_date).pages(10):
        for status in page:
            new_entry = []
            
            status = status._json                                    
            if status['lang'] != 'pt':
                continue                                        
            
            data['text'].append(status['text'])
            data['screen_name'].append(status['user']['screen_name'])
            data['created_at'].append(status['created_at'])
            data['retweet_count'].append(status['retweet_count'])
            data['favorite_count'].append(status['favorite_count'])
            data['friends_count'].append(status['user']['friends_count'])
            data['followers_count'].append(status['user']['followers_count'])
            
            data['user_id'].append(status['user']['id'])
            data['user_name'].append(status['user']['name'])
            data['user_location'].append(status['user']['location'])
            data['user_description'].append(status['user']['description'])
            
    return pd.DataFrame.from_dict(data, orient='index').transpose()

# %%
graacc_keywords = '#graacc OR #SolidariedadeGigante OR #carequinha OR #AçãoSocial OR #Cancer OR #HospitaldoAmor OR #unicef'
graacc_tweets = "./data/graacc_data.csv"
#call main method passing keywords and file path
df = write_tweets(graacc_keywords,  graacc_tweets)
#df.to_csv(graacc_tweets)

# %%
df.to_csv(graacc_tweets)

# %%
df
# Out:
#     search_phrase                                               text  \
# 0            None  RT @AquiCancer: #Câncer Eu me importo com você...
# 1            None  RT @sgnCancer: #Câncer Mil namorarão ao teu la...
# 2            None  RT @AquiCancer: #Câncer Você é inocente até be...
# 3            None  RT @AquiCancer: #Câncer Precisamos aprender a ...
# 4            None  RT @AquiCancer: #Câncer Eu me importo com você...
# ..            ...                                                ...
# 264          None  RT @AquiCancer: #Câncer Eu sei que preciso ser...
# 265          None  RT @sgnCancer: #Câncer Não é que eu não tenha ...
# 266          None  RT @sgnCancer: #Câncer Admiro quem me aguenta ...
# 267          None  RT @AquiCancer: #Câncer Eu sei que preciso ser...
# 268          None  RT @sgnCancer: #Câncer Eu odeio me acostumar a...
#
#          screen_name                      created_at retweet_count  \
# 0         crf_bbgata  Sat Dec 07 02:10:20 +0000 2019            39
# 1     Oliveira102521  Sat Dec 07 02:10:19 +0000 2019            11
# 2    BrennerGabriely  Sat Dec 07 02:09:47 +0000 2019            77
# 3            Diasxx1  Sat Dec 07 02:08:17 +0000 2019            53
# 4          tt_duda05  Sat Dec 07 02:05:04 +0000 2019            39
# ..               ...                             ...           ...
# 264         aiogurte  Fri Dec 06 23:48:36 +0000 2019            97
# 265    RainaraRaylla  Fri Dec 06 23:48:27 +0000 2019            18
# 266   MirellaSilva56  Fri Dec 06 23:48:26 +0000 2019            64
# 267       Horraynne4  Fri Dec 06 23:48:06 +0000 2019            97
# 268   MirellaSilva56  Fri Dec 06 23:47:53 +0000 2019            52
#
#     favorite_count friends_count followers_count              user_id  \
# 0                0           167             225  1172649736844828673
# 1                0           822            1103   881944251633893376
# 2                0           132              94  1106034764778229762
# 3                0           692             923  1014710722209730565
# 4                0           329             560  1086481306370957312
# ..             ...           ...             ...                  ...
# 264              0           710             485           2310066471
# 265              0            86               3  1203075659943297026
# 266              0           634             865           3039508683
# 267              0           281             402   998889037833342976
# 268              0           634             865           3039508683
#
#                   user_name                   user_location  \
# 0                     rafa✨
# 1                      M. 💨
# 2                      BI🇧🇼
# 3                     🧚🏼‍♀️                         10/08🥰🥰
# 4                   𝔭𝔯𝔦𝔫 💖👑               Beverly Hills, CA
# ..                      ...                             ...
# 264        A Problemática ⏳  https://www.facebook.com/tania
# 265          Raylla Rainara               Barbacena, Brasil
# 266            🌻 мілеllд🌻🎗️
# 267  docinho zangada 💆🏽‍♀️💚
# 268            🌻 мілеllд🌻🎗️
#
#                                       user_description
# 0    vem helenaaa👶😍 // solteiraa🥰// manicure💅 // @f...
# 1                      @YanOfc_10💏❤ @PamLindaaa765 👭❤.
# 2
# 3                      flamenguista ❤️🖤/@Gtorress80🥰🥰🥰
# 4                                   Pietra❤ @flamengo❤
# ..                                                 ...
# 264                              ⚓So just try again! ⚓
# 265  I've got nothing to lose nothing to prove........
# 266  Flamenguista🔴 Vinícius💙/Henry💙/Heloá💗👣 🌻oxum🌻/...
# 267  Have faith 🌸\nA vida me ensinou a dizer adeus ...
# 268  Flamenguista🔴 Vinícius💙/Henry💙/Heloá💗👣 🌻oxum🌻/...
#
# [269 rows x 12 columns]

# %%
#from tweepy import API
api.send_direct_message(recipient_id = 58998497, text = "teste teste")
# Out:
# DirectMessage(_api=<tweepy.api.API object at 0x7fe87c665590>, type='message_create', id='1203136154012463108', created_timestamp='1575684986962', message_create={'target': {'recipient_id': '58998497'}, 'sender_id': '58998497', 'message_data': {'text': 'teste teste', 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}}})

# %%
df[df['screen_name'].str.contains('elielsonfs')]
# Out:
#    search_phrase                                               text  \
# 19          None  #graacc #hackathon  #indra Soluções para arrec...
#
#    screen_name                      created_at retweet_count favorite_count  \
# 19  elielsonfs  Sat Dec 07 01:54:23 +0000 2019             0              0
#
#    friends_count followers_count   user_id          user_name user_location  \
# 19           298             135  58998497  Elielson Ferreira       Goiânia
#
#          user_description
# 19  Especialista em T.I.!

# %%
" OR ". join("as,dasd,asdfasdf".split(','))
# Out:
# 'as OR dasd OR asdfasdf'

# %%
" OR ". join("as".split(','))
# Out:
# 'as'
